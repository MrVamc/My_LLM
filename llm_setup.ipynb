# %% [markdown]
# <a href="https://colab.research.google.com/github/MrVamc/My_LLM/blob/main/llm_setup.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sys
print(sys.executable)
# Out:
# /usr/bin/python3

# %%
import torch
print(torch.__version__)
print(torch.cuda.is_available())
# Out:
# 2.11.0+cpu
# False

# %% [markdown]
# That's because the notebook may be using the CPU.
#
# For LLM work, we'll want a GPU when available.
#
# In Colab, go to:
#
# Runtime
#    ↓
# Change runtime type
#
# Then look for:
#
# Hardware accelerator
#
# Select:
#
# GPU
#
# and click Save.

# %%
import torch
print("PyTorch: ", torch.__version__)
print("CUDA available: ", torch.cuda.is_available())

if torch.cuda.is_available():
    print("CUDA device name: ", torch.cuda.get_device_name(0))
# Out:
# PyTorch:  2.11.0+cu128
# CUDA available:  True
# CUDA device name:  Tesla T4
